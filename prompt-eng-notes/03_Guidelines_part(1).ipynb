# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/colab_env/lib/python3.10/site-packages')

# %%
from google.colab import userdata
from together import Together

client = Together(api_key=userdata.get('TOGETHER_API_KEY'))

# %%
def get_completion(prompt, model="togethercomputer/llama-2-7b-chat"):
    response = client.completions.create(
        model=model,
        prompt=prompt,
        temperature=0.0,
    )
    return response.choices[0].text

# %%
text = """
You should express what you want a model to do by
providing instructions that are as clear and
specific as you can possibly make them.
This will guide the model towards the desired output,
and reduce the chances of receiving irrelevant
or incorrect responses. Don't confuse writing a
clear prompt with writing a short prompt.
In many cases, longer prompts provide more clarity
and context for the model, which can lead to
more detailed and relevant outputs.
"""

prompt = f"""
Summarize the text delimited by triple backticks
into a single sentence.
```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
just Generate a list of three made-up book titles along \
with their authors and genres.
Provide them in JSON format with the following keys and:
book_id, title, author, genre.
"""
response = get_completion(prompt)
print(response)

# %%
prompt = f"""
<child>: Teach me about patience.

<grandparent>: The river that carves the deepest \
valley flows from a modest spring; the \
grandest symphony originates from a single note; \
the most intricate tapestry begins with a solitary thread.

<child>: Teach me about resilience.

Provide only one response and do not continue the conversation.
"""
response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Provide only one response.

Input: Great product, 10/10
Sentiment: positive

Input: ______
Sentiment: negative

Input: The teacher was knowledgeable
Sentiment: ______

Input: ______
Sentiment: negative

Input: I love horse riding
Sentiment:
"""
response = get_completion(prompt)
print(response)
