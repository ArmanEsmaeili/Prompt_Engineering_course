# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/colab_env/lib/python3.10/site-packages')

# %%
from google.colab import userdata
from together import Together

# Initialize the Together client with the API key
client = Together(api_key=userdata.get('TOGETHER_API_KEY'))

# %%
def get_completion(prompt, model="togethercomputer/llama-2-7b-chat"):
    response = client.completions.create(
        model=model,
        prompt=prompt,
        temperature=0.0,  # Adjusting the temperature for better randomness control
    )
    return response.choices[0].text

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture,
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100)
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black,
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities:
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
"""
بررسی کلی
- بخشی از یک مجموعه زیبا از مبلمان اداری الهام گرفته از طراحی میانه قرن،
شامل کمدهای بایگانی، میزها، قفسه‌های کتاب، میزهای جلسه و موارد دیگر.
- دارای چندین گزینه برای رنگ پوسته و پایه.
- در دسترس با روکش پلاستیکی در پشت و جلوی صندلی (SWC-100)
یا روکش کامل (SWC-110) در ۱۰ نوع پارچه و ۶ نوع چرم.
- گزینه‌های پایان پایه شامل: استیل ضدزنگ، مشکی مات،
سفید براق یا کروم.
- صندلی با یا بدون دسته قابل انتخاب است.
- مناسب برای استفاده در محیط‌های خانگی یا تجاری.
- تأیید شده برای استفاده قراردادی.

ساختار
- پایه آلومینیومی با پوشش پلاستیکی و دارای ۵ چرخ.
- تنظیم ارتفاع صندلی به صورت پنوماتیک برای آسانی در بالا و پایین کردن.

ابعاد
- عرض: ۵۳ سانتی‌متر | ۲۰.۸۷ اینچ
- عمق: ۵۱ سانتی‌متر | ۲۰.۰۸ اینچ
- ارتفاع: ۸۰ سانتی‌متر | ۳۱.۵۰ اینچ
- ارتفاع نشیمن: ۴۴ سانتی‌متر | ۱۷.۳۲ اینچ
- عمق نشیمن: ۴۱ سانتی‌متر | ۱۶.۱۴ اینچ

گزینه‌ها
- گزینه‌های چرخ برای سطوح نرم یا سخت.
- دو نوع چگالی فوم نشیمن:
  متوسط (۱.۸ پوند/فوت مکعب) یا بالا (۲.۸ پوند/فوت مکعب)
- با یا بدون دسته‌های PU با ۸ موقعیت قابل تنظیم.

مواد
گلایدر از آلومینیوم ریخته‌گری شده با پوشش نایلونی اصلاح شده PA6/PA66.
- ضخامت پوسته: ۱۰ میلی‌متر.
نشیمن
- فوم HD36

کشور سازنده
- ایتالیا
"""

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""

# وظیفه شما این است که به تیم بازاریابی کمک کنید تا
# توضیحی برای یک وب‌سایت فروشگاهی درباره یک محصول ایجاد کند
# بر اساس برگه اطلاعات فنی
# بر اساس اطلاعات ارائه شده یک توضیح محصول بنویسید
# که در مشخصات فنی با سه بک‌تیک محصور شده‌اند
# مشخصات فنی: ```{fact_sheet_chair}```

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description must be exactly 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""

# توضیح باید دقیقاً شامل ۵۰ کلمه باشد.

response = get_completion(prompt)
print(response)

# %%
len(response.split(" "))

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

Technical specifications: ```{fact_sheet_chair}```
"""

# توضیح برای خرده‌فروشان مبلمان در نظر گرفته شده است، بنابراین باید فنی باشد و بر موادی که محصول از آنها ساخته شده تمرکز کند.

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

Use at most 50 words. End the description with including every 7-character product ID.

Technical specifications: ```{fact_sheet_chair}```
"""

# از حداکثر ۵۰ کلمه استفاده کنید. توضیح را با ذکر هر شناسه محصول ۷ کاراکتری به پایان برسانید.

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

Use at most 50 words. End the description with every 7-character product ID.

After the description, include a table that gives the
product's dimensions. The table should have two columns.
In the first column include the name of the dimension.
In the second column include the measurements in cm only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website.
Place the description in a <div> element. Use <h2> tags for subjects and <p> tags for paragraphs.

Technical specifications: ```{fact_sheet_chair}```
"""

# پس از توضیح، یک جدول شامل ابعاد محصول اضافه کنید. جدول باید دو ستون داشته باشد.
# در ستون اول نام بعد را شامل شود. در ستون دوم اندازه‌ها فقط به سانتی‌متر ذکر شود.
# جدول را با عنوان "ابعاد محصول" نامگذاری کنید.
# همه چیز را به‌صورت HTML فرمت کنید که در یک وب‌سایت استفاده شود.
# توضیح را در یک عنصر <div> قرار دهید. از تگ‌های <h2> برای عناوین و از تگ‌های <p> برای پاراگراف‌ها استفاده کنید.

response = get_completion(prompt)
print(response)

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
